# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

sns.set_style("darkgrid")

path = "C:\\Users\hp\Desktop\X\SM-RuleMiner\Working code\Logs"

# %%
df = pd.read_excel(path + "\orignal_fitness_test_log.xlsx")
df.shape
# Out:
# (92, 5)

# %%
cols = df.columns[1:].tolist()

for col in cols:
    print(col)
    sns.histplot(df[col])
    plt.show()
    print("\n-------------------------------------\n")
# Out:
# P_avg
# -------------------------------------
#
# P_best
# -------------------------------------
#
# N_avg
# -------------------------------------
#
# N_best
# -------------------------------------
